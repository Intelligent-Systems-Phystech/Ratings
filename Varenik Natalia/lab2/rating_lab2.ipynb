# %% [markdown]
# ### Сильная рассогласованность экспертов

# %%
import numpy as np
np.random.seed(38)

n_obj = 5
n_exp = 100
x = np.random.normal(0, 1, (n_obj, n_exp))

x = x.argsort(axis=0)

# %%
none_prob = 0.1
mask = np.random.binomial(1, none_prob, x.shape).astype(bool)
x[mask] = -1
x = x / x.max(axis=0, keepdims=True)

# %%
mask = x < 0
x[mask] = -1

# %%
clusters = []

def dist(x, y):
    return ((x-y)**2).sum()**0.5


def proccess_point(new_p, clusters, thresh = 1.):
    added = 0
    for i in range(len(clusters)):
        in_cluster = np.any([dist(new_p, p) < thresh for p in clusters[i]])
        if in_cluster:
            added = True
            clusters[i].append(new_p)


    if not added:
        clusters.append([new_p])
    return clusters

# %%
from sklearn.cluster import DBSCAN

clustering = DBSCAN(eps=0.5, min_samples=1)
n_cluster_list = []
for n in range(n_exp):
    x_n = x.T[:n+1] 
    clustering.fit(x_n)
    n_cluster = len(set(clustering.labels_))
    n_cluster_list.append(n_cluster)

# %%
import matplotlib.pyplot as plt

plt.plot(range(n_exp), n_cluster_list)
plt.xlabel('Количество экспертов')
plt.ylabel('Количество кластеров');

# %% [markdown]
# ### Эксперты имеют определенные типы мнений

# %%
import itertools

n_clust = 5
permuts = list(itertools.permutations(range(n_obj)))
np.random.shuffle(permuts)
select_permuts = permuts[:n_clust]

# %%
landmarks = np.array([np.random.random() for _ in range(n_clust - 1)] + [1])
landmarks = np.sort(landmarks)

# %%
n_exp = 100
x = []
for _ in range(n_exp):
    p = np.random.random()
    i = (landmarks < p).sum()
    x_i = np.random.normal(select_permuts[i], .1)
    x.append(x_i)
    
x = np.array(x).T
#x = x.argsort(axis=0)

none_prob = 0.01
mask = np.random.binomial(1, none_prob, x.shape).astype(bool)
x[mask] = -1e3

#x = x.argsort(axis=0)
#x = x / x.max(axis=0, keepdims=True)

# %%
for j in range(x.shape[1]):
    x_col = x[:,j]
    mask = x_col > -1e3
    if np.sum(mask) > 1:
        x[mask, j] = x_col[mask].argsort() / (np.sum(mask) - 1)
    else:
        x[mask, j] = 0

# %%
x[x==-1e3] = -1

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

n_cluster_list = []
for n in range(100):
    x_n = x.T[:n+1] 
    clustering = DBSCAN(eps=0.5, min_samples=2).fit(x_n)
    n_cluster = len(set(clustering.labels_))
    n_cluster_list.append(n_cluster)
    
plt.plot(range(100), n_cluster_list)
plt.xlabel('Количество экспертов')
plt.ylabel('Количество кластеров');

# %% [markdown]
# ### Получение рейтинга

# %%
inp = '''4				9	5					3	9	7	6
2	6	4	8	7	4	3	3		4	6	3	4	2
5	1	5	5	4	3	8	4	2	3	5	5	6	
7	7	2	3	2	8	4	6	3	5		6	5	1
	2	7	2	6	7	5	5	7		7	7	8	
3	4	1	9	5		1	1	6	6	1	2	2	4
	3	3		1	2	6	2	1	1	2	8		5
6	5	8	4	8	1	7	7	4	7		1	1	
1	8	6	1	3	6	2	8	5	2	4	4	3	3'''
 
x = np.array([line.split('\t') for line in inp.split('\n')]).astype(object)
x[x!=''] = x[x!=''].astype(int)
x[x==''] = None

# %%
x
# Out:
# array([[4, None, None, None, 9, 5, None, None, None, None, 3, 9, 7, 6],
#        [2, 6, 4, 8, 7, 4, 3, 3, None, 4, 6, 3, 4, 2],
#        [5, 1, 5, 5, 4, 3, 8, 4, 2, 3, 5, 5, 6, None],
#        [7, 7, 2, 3, 2, 8, 4, 6, 3, 5, None, 6, 5, 1],
#        [None, 2, 7, 2, 6, 7, 5, 5, 7, None, 7, 7, 8, None],
#        [3, 4, 1, 9, 5, None, 1, 1, 6, 6, 1, 2, 2, 4],
#        [None, 3, 3, None, 1, 2, 6, 2, 1, 1, 2, 8, None, 5],
#        [6, 5, 8, 4, 8, 1, 7, 7, 4, 7, None, 1, 1, None],
#        [1, 8, 6, 1, 3, 6, 2, 8, 5, 2, 4, 4, 3, 3]], dtype=object)

# %%
def get_rating(x):
    for j in range(x.shape[1]):
        mask = x[:,j] != None
        if np.sum(mask) > 1:
            sort = np.sort(x[mask, j])
            temp = np.array([np.argmax((sort==i)) for i in x[mask, j]]) / (np.sum(mask) - 1)
            x[mask, j] = temp
        else:
            x[mask, j] = 0
            
    for i in range(x.shape[0]):
        mask = x[i] == None
        x[i,mask] = np.median(x[i,~mask])
    rating = x.sum(axis=1)
    return rating.argsort()

# %%
my_rating = get_rating(x)

# %%
product_names = np.array(['Устрицы',
                          'Арахиc соленый',
                          'Молоко  2,5%',
                          'Макароны',
                          'Овсяное молоко 3.2%',
                          'Шоколад',
                          'Сырок "РОСТАГРОЭКСПОРТ"',
                          'Кефир 3.2%',
                          'Гречневая крупа']
                        )
product_names[my_rating]
# Out:
# array(['Сырок "РОСТАГРОЭКСПОРТ"', 'Шоколад', 'Гречневая крупа',
#        'Арахиc соленый', 'Молоко  2,5%', 'Макароны', 'Кефир 3.2%',
#        'Овсяное молоко 3.2%', 'Устрицы'], dtype='<U23')

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(13, 13))
plt.subplots_adjust(hspace=0.15, wspace=0.25)

my_rating = [9, 4, 5, 6, 8, 2, 1, 7, 3]
med_rating = [9, 4, 5, 6, 7, 2, 2, 7, 3]
mean_rating = [8.470588235, 4.705882353, 4.529411765, 5.294117647, 6.823529412, 2.470588235, 2.235294118, 6.588235294, 4.058823529]
rating1 = [9, 4, 5, 6, 7, 1, 2, 8, 3]
rating2 = [9, 3, 8, 4, 5, 1, 6, 7, 2]
rating3 = [9, 5, 4, 6, 7, 3, 1, 8, 2]

axs[0, 0].scatter(my_rating, med_rating)
axs[0, 0].plot([0, 10], [0, 10], c='r')
axs[0, 0].set_ylabel('Медиана', fontsize=12)
axs[0, 0].set_xlabel('Мой', fontsize=12)
axs[0, 0].grid(True)

axs[0, 1].scatter(my_rating, rating1)
axs[0, 1].plot([0, 10], [0, 10], c='r')
axs[0, 1].set_ylabel('Частный 1', fontsize=12)
axs[0, 1].set_xlabel('Мой', fontsize=12)
axs[0, 1].grid(True)

axs[1, 0].scatter(my_rating, rating2)
axs[1, 0].plot([0, 10], [0, 10], c='r')
axs[1, 0].set_ylabel('Частный 2', fontsize=12)
axs[1, 0].set_xlabel('Мой', fontsize=12)
axs[1, 0].grid(True)

axs[1, 1].scatter(my_rating, rating3)
axs[1, 1].plot([0, 10], [0, 10], c='r')
axs[1, 1].set_ylabel('Частный 3', fontsize=12)
axs[1, 1].set_xlabel('Мой', fontsize=12)
axs[1, 1].grid(True)

for i, txt in enumerate(product_names):
    if i in [6, 7]:
        axs[0, 0].annotate(txt, (my_rating[i], med_rating[i]+0.3), fontsize=12)
    else: 
        axs[0, 0].annotate(txt, (my_rating[i], med_rating[i]), fontsize=12)
    axs[0, 1].annotate(txt, (my_rating[i], rating1[i]), fontsize=12)
    axs[1, 0].annotate(txt, (my_rating[i], rating2[i]), fontsize=12)
    axs[1, 1].annotate(txt, (my_rating[i], rating3[i]), fontsize=12)

#fig.suptitle('Сравнение рейтингов', fontsize=18)
plt.show();

# %% [markdown]
# ### Отказ от принятия решения

# %%
import nltk

# %%
inp = '''9	4	5	6	8	2	1	7	3
9	4	5	6	7	1	2	8	3
7	3	5	6	9	2	1	8	4
9	4	5	6	7	2	1	8	3
8	7	4	2	6	5	1	9	3
9	3	8	4	5	1	6	7	2
7	5	3	4	8	2	1	9	6
9	6	7	4	8	2	1	3	5
8	5	3	7	4	1	2	6	9
7	6	9	2	4	8	3	5	1
9	5	4	6	7	3	1	8	2
8	9	5	6	7	1	2	4	3
8	7	4	2	6	5	1	9	3
7	1	4	9	6	3	5	2	8
9	4	5	6	7	2	3	8	4
9	3	1	7	4	8	6	2	5
9	4	5	6	8	1	2	7	3
9	4	3	3	7	3	2	4	6
9	5	4	8	6	1	2	7	3
9	4	3	5	8	6	1	7	2
9	4	5	8	7	2	1	6	3'''
x = np.array([line.split('\t') for line in inp.split('\n')]).astype(object)
x[x!=''] = x[x!=''].astype(int)
x = x.T

# %%
x
# Out:
# array([[9, 9, 7, 9, 8, 9, 7, 9, 8, 7, 9, 8, 8, 7, 9, 9, 9, 9, 9, 9, 9],
#        [4, 4, 3, 4, 7, 3, 5, 6, 5, 6, 5, 9, 7, 1, 4, 3, 4, 4, 5, 4, 4],
#        [5, 5, 5, 5, 4, 8, 3, 7, 3, 9, 4, 5, 4, 4, 5, 1, 5, 3, 4, 3, 5],
#        [6, 6, 6, 6, 2, 4, 4, 4, 7, 2, 6, 6, 2, 9, 6, 7, 6, 3, 8, 5, 8],
#        [8, 7, 9, 7, 6, 5, 8, 8, 4, 4, 7, 7, 6, 6, 7, 4, 8, 7, 6, 8, 7],
#        [2, 1, 2, 2, 5, 1, 2, 2, 1, 8, 3, 1, 5, 3, 2, 8, 1, 3, 1, 6, 2],
#        [1, 2, 1, 1, 1, 6, 1, 1, 2, 3, 1, 2, 1, 5, 3, 6, 2, 2, 2, 1, 1],
#        [7, 8, 8, 8, 9, 7, 9, 3, 6, 5, 8, 4, 9, 2, 8, 2, 7, 4, 7, 7, 6],
#        [3, 3, 4, 3, 3, 2, 6, 5, 9, 1, 2, 3, 3, 8, 4, 5, 3, 6, 3, 2, 3]],
#       dtype=object)

# %%
def paste_missings(x, prob):
    mask = np.random.binomial(1, prob, x.shape).astype(bool)
    x_copy = x.copy()
    x_copy[mask] = None
    return x_copy

# %%
rating_0 = get_rating(x.copy())
rating_0
# Out:
# array([6, 5, 8, 2, 1, 3, 7, 4, 0])

# %%
probs = np.linspace(0, 0.9, 30)
dists = []
for p in probs:
    sample_dist = []
    for _ in range(100):
        x_with_miss = paste_missings(x, p)
        try:
            rating = get_rating(x_with_miss)
        except:
            continue
        
        dist = nltk.edit_distance(''.join(rating_0.astype(str)), ''.join(rating.astype(str)), transpositions=True)
        sample_dist.append(dist)
    dists.append(np.mean(sample_dist))
# Out:
# /usr/local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %%
plt.plot(probs, dists)
plt.xlabel('Доля пропусков')
plt.ylabel('Ошибка')
plt.title('График ошибки от количества пропусков');
